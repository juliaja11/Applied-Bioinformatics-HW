# %% [markdown]
# # 1.6 awk
#
# This notebook will demonstrate the basics of using `awk` to extract specific fields from within data files.

# %% [markdown]
# #### manual inspection of `artists.txt`
#
# There are at least two options for loading `artists.txt` into your favorite spreadsheet program:
#
# * you already have the file on your computer somewhere on your file system, so you can load it from there (if you can figure it out)
# * you can download the text file from https://raw.githubusercontent.com/SuLab/Applied-Bioinformatics/master/Module-1_bash-jupyter-git/data/art/artists.txt
#
# Note that every row has four columns.

# %% [markdown]
# #### confirm using awk that each row has four columns
# Find and fix the error.
#
# ```
# %%bash
# awk '{print NF}' artists.txt
# ```

# %%
# %%bash
# awk '{FS="\t";print NF}' data/art/artists.txt
# Out:
# 8
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4

# %% [markdown]
# #### Print the third column
# Find and fix the error.
# ```
# %%bash
# awk '{print $3}' artists.txt
# ```

# %%
# %%bash
# awk '{FS="\t";print $3}' data/art/artists.txt
# Out:
# (1581-1662)
# Romanticism
# Romanticism
# Romanticism
# Baroque
# Romanticism
# Baroque
# Realism
# Northern Renaissance
# Realism
# Romanticism
# Baroque
# Baroque
# Early Renaissance
# Medieval
# Early Renaissance
# Realism
# Medieval
# Medieval
# Early Renaissance
# High Renaissance
# Early Renaissance
# Baroque
# Baroque
# Baroque
# Rococo
# Neoclassicism
# Impressionism
# Baroque
# Baroque
# Mannerism
# Baroque
# Baroque
# Rococo
# Romanticism
# Baroque
# Baroque
# Rococo
# Baroque
# Baroque
# Mannerism
# Romanticism
# Rococo
# Baroque
# Baroque
# Baroque
# Neoclassicism
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Neoclassicism
# Mannerism
# Baroque
# Baroque
# Baroque
# Baroque
# Mannerism
# Romanticism
# Baroque
# Baroque
# Baroque
# Realism
# Romanticism
# Romanticism
# Romanticism
# Rococo
# Baroque
# Neoclassicism
# Baroque
# Baroque
# Baroque
# Rococo
# Rococo
# Rococo
# Neoclassicism
# Romanticism
# Northern Renaissance
# Romanticism
# Romanticism
# Baroque
# Baroque
# Romanticism
# Northern Renaissance
# Baroque
# Baroque
# Neoclassicism
# Rococo
# Mannerism
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Northern Renaissance
# Romanticism
# Mannerism
# Realism
# Early Renaissance
# High Renaissance
# Mannerism
# Realism
# Baroque
# High Renaissance
# Baroque
# Romanticism
# Mannerism
# Baroque
# Realism
# Romanticism
# Baroque
# Baroque
# Baroque
# Realism
# Neoclassicism
# Neoclassicism
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Early Renaissance
# Baroque
# Baroque
# Northern Renaissance
# Northern Renaissance
# Neoclassicism
# Medieval
# Early Renaissance
# Medieval
# Early Renaissance
# Medieval
# High Renaissance
# High Renaissance
# Neoclassicism
# Realism
# Rococo
# Medieval
# Early Renaissance
# Baroque
# Medieval
# Early Renaissance
# Mannerism
# Mannerism
# Early Renaissance
# Early Renaissance

# %% [markdown]
# #### Use `uniq` (and another command) to find the most common art periods
# Find and fix the error(s).
# ```
# %%bash
# awk '{print $3}' artists.txt | uniq
# ```

# %%
# %%bash
# awk '{FS="\t";print $3}' data/art/artists.txt|sort|uniq -c
# Out:
#    1 (1581-1662)
#   60 Baroque
#   12 Early Renaissance
#    5 High Renaissance
#    1 Impressionism
#   10 Mannerism
#    8 Medieval
#   10 Neoclassicism
#    6 Northern Renaissance
#    9 Realism
#   10 Rococo
#   18 Romanticism

# %% [markdown]
# ## Homework

# %% [markdown]
# ### HW1: Repeat the above command (finding the most common art periods) restricting to Dutch painters only.
# HINT: start by searching/filtering for Dutch painters...

# %%
# %%bash
# grep "Dutch painter" data/art/artists.txt|awk '{FS="\t";print $3}'|sort|uniq -c
# Out:
#   16 Baroque
#    1 Neoclassicism
#    1 Realism
#    2 Rococo
#    4 Romanticism
#    1 van

# %% [markdown]
# ### HW2: Find the most common last names among all artists in `artists.txt`.
# HINT: you will use `awk`, `sort`, and `uniq`, and you may use one or more of those commands multiple times

# %%
# %%bash
# awk '{FS="\t";print $1}'data/art/artists.txt|sort|uniq -c||sort -n
# Out:
#    1 AAGAARD, Carl Frederik
#    1 ABADIA, Juan de la
#    1 ABAQUESNE, Masséot
#    1 ABBATE, Niccolò dell'
#    1 ABBATI, Giuseppe
#    1 ABBATINI, Guido Ubaldo
#    1 ABBONDI, Antonio di Pietro (see SCARPAGNINO)
#    1 ABEELE, Pieter van
#    1 ABILDGAARD, Nicolai
#    1 ABONDIO, Antonio
#    1 ACERO Y AREBO, Vicente
#    1 ACHENBACH, Oswald
#    1 ADAM, Albrecht
#    1 ADAM, Lambert-Sigisbert
#    1 ADAM, Nicolas-Sébastien
#    1 ADAM, Robert
#    1 ADAM-SALOMON, Antoine-Samuel
#    1 ADELCRANTZ, Carl Fredrik
#    1 ADEMOLLO, Luigi
#    1 ADLER, Salomon
#    1 ADOLFZOON, Christoph (see ADOLPHI, Christoffel)
#    1 ADOLPHI, Christoffel
#    1 ADRIAEN VAN UTRECHT (see UTRECHT, Adriaen van)
#    1 ADRIAENSSEN, Alexander
#    1 ADRIANO FIORENTINO
#    1 AELST, Willem van
#    1 AENVANCK, Theodoor
#    1 AERT VAN ORT
#    1 AERTSEN, Pieter
#    1 AGASSE, Jacques-Laurent
#    1 AGNOLO DA SIENA (see AGNOLO DI VENTURA)
#    1 AGNOLO DI POLO
#    1 AGNOLO DI VENTURA
#    1 AGOSTINO DI DUCCIO
#    1 AGOSTINO DI GIOVANNI
#    1 AGOSTINO VENEZIANO (see MUSI, Agostino dei)
#    1 AGRATE, Gian Francesco Ferrari d'
#    1 AGUADO LÓPEZ, Antonio
#    1 AIVAZOVSKY, Ivan Konstantinovich
#    1 AKEN, Joseph van
#    1 AKOTANTOS, Angelos
#    1 ALBA, Macrino d'
#    1 ALBANI, Francesco
#    1 ALBEREGNO, Jacobello
#    1 ALBERTI, Antonio
#    1 ALBERTI, Cherubino
#    1 ALBERTI, Giovanni
#    1 ALBERTI, Leon Battista
#    1 ALBERTINELLI, Mariotto
#    1 KILIAN, Wolfgang
#    1 KINSOEN, François-Joseph
#    1 KISS, August Karl Edouard
#    1 KISS, Bálint
#    1 KLEINER, Salomon
#    1 KLENZE, Leo von
#    1 KLESECKER, Justus (see GLESKER, Justus)
#    1 KLINGER, Max
#    1 KLOCKER, Hans
#    1 KLODT, Mikhail Konstantinovich
#    1 KLODT, Pyotr Karlovich
#    1 KNEBEL, Franz
#    1 KNELLER, Sir Godfrey
#    1 KNIJFF, Jacob
#    1 KNIJFF, Wouter
#    1 KNIP, Henriëtte
#    1 KNIP, Henriëtte Geertruida
#    1 KNIP, Josephus Augustus
#    1 KNIP, Mattheus Derk
#    1 KNIP, Nicolaas Frederik
#    1 KNOBELSDORFF, Georg Wenceslaus von
#    1 KNOLLER, Martin
#    1 KNYFF, Jacob (see KNIJFF, Jacob)
#    1 KNYFF, Wouter (see KNIJFF, Wouter)
#    1 KNÜPFER, Nicolaus
#    1 KOBELL, Franz
#    1 KOBELL, Hendrik
#    1 KOBELL, Jan I
#    1 KOBELL, Jan II
#    1 KOBELL, Wilhelm von
#    1 KOBERGER, Anton
#    1 KOCH, Joseph Anton
#    1 KOEBERGER, Wenzel (see COBERGHER, Wenceslas)
#    1 KOEDIJCK, Isaack
#    1 KOEKKOEK, Barend Cornelis
#    1 KOERBECKE, Johann
#    1 KOETS, Roelof
#    1 KOKORINOV, Alexander Filippovich
#    1 KOLBE, Carl Wilhelm
#    1 KOLLONITSCH, Christian
#    1 KOLUNIĆ, Martin (see ROTA, Martino)
#    1 KOMPE, Jan ten (see COMPE, Jan ten)
#    1 KONINCK, Daniël de
#    1 KONINCK, David de (see CONINCK, David de)
#    1 KONINCK, Philips
#    1 KONINCK, Salomon
#    1 KONRAD von Soest
#    1 KOPISCH, August
#    1 KÖNIG, Johann
#    1 KŘBKE, Christen
#    1 TACCA, Ferdinando
#    1 TACCA, Pietro
#    1 TACCONE, Paolo (see PAOLO ROMANO)
#    1 TADDEO DI BARTOLO
#    1 TADDEO DI FERRARA (see CRIVELLI, Taddeo)
#    1 TADOLINI, Scipione
#    1 TALENTI, Francesco
#    1 TALENTI, Simone
#    1 TALPA, Bartolo
#    1 TAMAGNI, Vincenzo
#    1 TAMAGNINO, Antonio (see PORTA, Antonio della)
#    1 TAMM, Franz Werner von
#    1 TANZIO DA VARALLO
#    1 TARAVAL, Guillaume-Thomas-Raphaël
#    1 TARAVAL, Hugues
#    1 TARAVAL, Louis-Gustave
#    1 TARBELL, Edmund Charles
#    1 TARCHIANI, Filippo
#    1 TARDIEU, Nicolas-Henry
#    1 TARGONE, Cesare
#    1 TARSIA, Antonio
#    1 TARUFFI, Emilio
#    1 TASSAERT, Jean-Pierre-Antoine
#    1 TASSAERT, Octave
#    1 TASSEL, Jean
#    1 TASSI, Agostino
#    1 TAUNAY, Nicolas Antoine
#    1 TEDESCO, Carlo (see SFERINI, Carlo Leopoldo)
#    1 TEDESCO, Giovanni Paolo (see SCHOR, Johann Paul)
#    1 TEERLINC, Levina
#    1 TELEPY, Károly
#    1 TEMANZA, Tommaso
#    1 TEMPEL, Abraham van den
#    1 TEMPESTA, Antonio
#    1 TEMPESTA, Pietro (see MULIER, Pieter the Younger)
#    1 TENERANI, Pietro
#    1 TENGNAGEL, Jan
#    1 TENIERS, Abraham
#    1 TENIERS, David the Elder
#    1 TENIERS, David the Younger
#    1 TERBORCH, Gerard
#    1 TERBRUGGHEN, Hendrick
#    1 TERILLI, Francesco
#    1 TERRENI, Giuseppe Maria
#    1 TERZIO, Francesco
#    1 TESSIN, Nicodemus the Elder
#    1 TESSIN, Nicodemus the Younger
#    1 TESTA, Pietro
#    1 TESTELIN, Henri
#    1 TETRODE, Willem Danielsz van
# 1
